# %%
# %sql
CREATE CATALOG IF NOT EXISTS nyc_yellow_taxi;
USE CATALOG nyc_yellow_taxi;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;
SHOW DATABASES FROM nyc_yellow_taxi
